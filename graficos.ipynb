# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

#df = pd.read_csv('resultados.csv', delimiter=',')
#df.sort_values(by='Tiempo_s')

# %%
plt.clf()
df.sort_values(by='Informantes').plot(x='Informantes', y='Tiempo_s', logy='true')
plt.show()

# %%
df.groupby('Informantes').mean()

plt.clf()
df.groupby('Informantes').mean().plot(y='Tiempo_s', logy='true')
plt.show()

# %%
#df[df.Informantes==20].sort_values(by='Tiempo_s')
df[df.Informantes==20].groupby('Respuestas').mean().sort_values(by='Tiempo_s')
# Out:
#             Informantes  Agentes_Confiables  Tiempo_s
# Respuestas
# 94                 20.0                 2.2  0.000359
# 97                 20.0                 1.6  0.000377
# 88                 20.0                 1.8  0.000386
# 99                 20.0                 1.6  0.000386
# 92                 20.0                 1.7  0.000433
# 96                 20.0                 1.3  0.000433
# 95                 20.0                 1.5  0.000438
# 83                 20.0                 2.0  0.000480
# 98                 20.0                 2.6  0.000508
# 79                 20.0                 1.8  0.000525
# 93                 20.0                 1.7  0.000567
# 87                 20.0                 2.3  0.000567
# 91                 20.0                 2.7  0.000591
# 89                 20.0                 1.6  0.000606
# 80                 20.0                 2.6  0.000622
# 84                 20.0                 3.0  0.000636
# 85                 20.0                 2.1  0.000641
# 86                 20.0                 2.1  0.000647
# 73                 20.0                 2.8  0.000680
# 90                 20.0                 2.3  0.000681
# 78                 20.0                 2.4  0.000720
# 76                 20.0                 2.6  0.000722
# 69                 20.0                 3.5  0.000736
# 82                 20.0                 2.7  0.000776
# 68                 20.0                 3.8  0.000795
# 77                 20.0                 2.4  0.000801
# 67                 20.0                 3.9  0.000818
# 71                 20.0                 3.5  0.000828
# 72                 20.0                 3.4  0.000860
# 70                 20.0                 3.4  0.000894
# ...                 ...                 ...       ...
# 46                 20.0                 8.2  0.006329
# 6                  20.0                17.4  0.007288
# 37                 20.0                 9.8  0.009425
# 25                 20.0                11.8  0.009544
# 33                 20.0                10.7  0.009756
# 32                 20.0                10.9  0.010168
# 28                 20.0                10.8  0.010958
# 24                 20.0                12.3  0.012288
# 30                 20.0                10.4  0.013003
# 29                 20.0                11.0  0.013562
# 9                  20.0                16.6  0.013697
# 31                 20.0                10.5  0.014137
# 8                  20.0                16.9  0.014719
# 27                 20.0                11.4  0.014798
# 22                 20.0                12.7  0.015750
# 17                 20.0                14.4  0.017068
# 10                 20.0                16.5  0.017108
# 13                 20.0                15.4  0.017655
# 7                  20.0                16.5  0.018222
# 23                 20.0                11.8  0.019048
# 26                 20.0                11.2  0.020210
# 14                 20.0                14.6  0.020679
# 15                 20.0                14.8  0.021890
# 21                 20.0                13.1  0.022369
# 12                 20.0                14.9  0.030045
# 20                 20.0                12.9  0.030137
# 16                 20.0                15.1  0.030717
# 19                 20.0                14.3  0.033057
# 18                 20.0                13.8  0.033193
# 11                 20.0                15.1  0.035909
#
# [95 rows x 3 columns]

# %%
df[df.Informantes==20].groupby('Respuestas').mean().sort_values(by='Tiempo_s').apply(lambda Tiempo_s : Tiempo_s ** 1/2)
# Out:
#             Informantes  Agentes_Confiables  Tiempo_s
# Respuestas
# 22                 10.0                6.15  0.011473

# %%
plt.clf()
df[df.Informantes==20].groupby('Respuestas').mean().plot(y='Tiempo_s', logy='true')
plt.show()
# Out:
# /home/lucas/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=22.0, right=22.0
#   'left=%s, right=%s') % (left, right))

# %%
plt.clf()
df[df.Informantes==20].groupby('Respuestas').mean().apply(lambda Tiempo_s : Tiempo_s ** 1/3).plot(y='Tiempo_s')
plt.show()

# %%
plt.clf()
df.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p0 = pd.read_csv('resultados_p0_informantes_5_a_20_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p0.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p1a = pd.read_csv('resultados_p1a_informantes_5_a_20_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p1a.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p1b = pd.read_csv('resultados_p1b_informantes_5_a_20_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p1b.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p2 = pd.read_csv('resultados_p2_informantes_5_a_20_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p2.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p0 = pd.read_csv('resultados_p0_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p0.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p1a = pd.read_csv('resultados_p1a_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p1a.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p1b = pd.read_csv('resultados_p1b_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p1b.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p2 = pd.read_csv('resultados_p2_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p2.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()
