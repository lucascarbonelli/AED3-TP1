# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt

#df = pd.read_csv('resultados.csv', delimiter=',')
#df.sort_values(by='Tiempo_s')

# %%
#plt.clf()
#df.sort_values(by='Informantes').plot(x='Informantes', y='Tiempo_s', logy='true')
#plt.show()

# %%
#df.groupby('Informantes').mean()

#plt.clf()
#df.groupby('Informantes').mean().plot(y='Tiempo_s', logy='true')
#plt.show()

# %%
#df[df.Informantes==20].sort_values(by='Tiempo_s')
#df[df.Informantes==20].groupby('Respuestas').mean().sort_values(by='Tiempo_s')

# %%
#df[df.Informantes==20].groupby('Respuestas').mean().sort_values(by='Tiempo_s').apply(lambda Tiempo_s : Tiempo_s ** 1/2)

# %%
#plt.clf()
#df[df.Informantes==20].groupby('Respuestas').mean().plot(y='Tiempo_s', logy='true')
#plt.show()

# %%
#plt.clf()
#df[df.Informantes==20].groupby('Respuestas').mean().apply(lambda Tiempo_s : Tiempo_s ** 1/3).plot(y='Tiempo_s')
#plt.show()

# %%
#plt.clf()
#df.groupby('Respuestas').mean().plot(y='Tiempo_s')
#plt.show()

# %%
df_i_p0 = pd.read_csv('resultados_p0_informantes_5_a_25_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p0.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p1a = pd.read_csv('resultados_p1a_informantes_5_a_25_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p1a.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p1b = pd.read_csv('resultados_p1b_informantes_5_a_25_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p1b.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_i_p2 = pd.read_csv('resultados_p2_informantes_5_a_25_opiniones_20.csv', delimiter=',')
plt.clf()
df_i_p2.groupby('Informantes').mean().plot(y='Tiempo_s')
plt.show()

# %%
data = {'Informantes' : df_i_p2.Informantes, 'Sin cotas' : df_i_p0.Tiempo_s, 'Cota A' : df_i_p1a.Tiempo_s, 'Cota B' : df_i_p1b.Tiempo_s, 'Cotas A + B' : df_i_p2.Tiempo_s}
df_i = pd.DataFrame(data)

plt.clf()
grafico_i = df_i.groupby('Informantes').mean().plot(logy='true')
grafico_i.set_ylabel('Tiempo (log(s))')
grafico_i.set_title('Tiempo en funcion de la cantidad de informantes')
plt.show()

df_i.groupby('Informantes').mean()
# Out:
#                Cota A    Cota B  Cotas A + B  Sin cotas
# Informantes
# 5            0.000005  0.000004     0.000005   0.000004
# 6            0.000006  0.000005     0.000005   0.000005
# 7            0.000015  0.000014     0.000014   0.000015
# 8            0.000021  0.000018     0.000018   0.000021
# 9            0.000056  0.000052     0.000051   0.000058
# 10           0.000063  0.000053     0.000056   0.000062
# 11           0.000138  0.000119     0.000117   0.000144
# 12           0.000284  0.000229     0.000226   0.000290
# 13           0.000557  0.000420     0.000375   0.000592
# 14           0.000942  0.000776     0.000612   0.001115
# 15           0.001790  0.001469     0.001184   0.002187
# 16           0.003921  0.003007     0.002627   0.004383
# 17           0.006644  0.004663     0.003444   0.007328
# 18           0.014390  0.008049     0.007622   0.014177
# 19           0.023885  0.012669     0.010718   0.025116
# 20           0.040148  0.019309     0.016412   0.043827
# 21           0.089676  0.044587     0.035277   0.097134
# 22           0.214790  0.088660     0.074837   0.231696
# 23           0.389070  0.169084     0.118522   0.431899
# 24           0.715951  0.425716     0.318878   0.827047

# %%
df_r_p0 = pd.read_csv('resultados_p0_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p0.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p1a = pd.read_csv('resultados_p1a_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p1a.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p1b = pd.read_csv('resultados_p1b_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
df_r_p1b.groupby('Respuestas').mean().plot(y='Tiempo_s')
plt.show()

# %%
df_r_p2 = pd.read_csv('resultados_p2_informantes_20_opiniones_0_a_100.csv', delimiter=',')
plt.clf()
grafico_r_p2 = df_r_p2.groupby('Respuestas').mean().plot(y='Tiempo_s', legend=False)
grafico_r_p2.set_ylabel('Tiempo (s)')
grafico_r_p2.set_title('Tiempo en funcion de la cantidad de respuestas (Cotas A + B)')
plt.show()

# %%
plt.clf()
df_r_p2[df_r_p2.Respuestas<10].groupby('Respuestas').min().apply(lambda Tiempo_s : Tiempo_s ** 1).plot(y='Tiempo_s', legend=False)
plt.show()

# %%
df_r_p2_10_20 = df_r_p2[df_r_p2.Respuestas<=25]
data_r_p2_box = {'Respuestas' : df_r_p2_10_20.Respuestas, 'Tiempo' : df_r_p2_10_20.Tiempo_s}
df_r_p2_box = pd.DataFrame(data_r_p2_box)
plt.clf()
grafico_r = df_r_p2_box.boxplot(by='Respuestas')
grafico_r.set_ylabel('Tiempo (s)')
grafico_r.set_xlabel('Respuestas')
#grafico_r.set_title('Tiempo en funcion de la cantidad de respuestas (boxplot)')
grafico_r.set_title('')
plt.suptitle('')
plt.show()
#df_r_p2_box.sort_values('Respuestas')
#df_r_p2_10_20.sort_values('Respuestas')

# %%
data_r = {'Respuestas' : df_r_p2.Respuestas, 'Sin cotas' : df_r_p0.Tiempo_s, 'Cota A' : df_r_p1a.Tiempo_s, 'Cota B' : df_r_p1b.Tiempo_s, 'Cotas A + B' : df_r_p2.Tiempo_s}
df_r = pd.DataFrame(data_r)

plt.clf()
grafico_r = df_r.groupby('Respuestas').mean().plot()
grafico_r.set_ylabel('Tiempo (s)')
grafico_r.set_title('Tiempo en funcion de la cantidad de respuestas')
plt.show()

df_r
# Out:
#        Cota A    Cota B  Cotas A + B  Respuestas  Sin cotas
# 0    0.179757  0.000005     0.000005           0   0.177198
# 1    0.234909  0.000006     0.000006           1   0.229025
# 2    0.272854  0.000010     0.000010           2   0.269921
# 3    0.318181  0.000014     0.000015           3   0.311732
# 4    0.138205  0.000200     0.000168           4   0.137443
# 5    0.365093  0.003734     0.003726           5   0.359464
# 6    0.316139  0.006132     0.005016           6   0.306391
# 7    0.314110  0.014921     0.015155           7   0.311708
# 8    0.208238  0.001542     0.001651           8   0.199123
# 9    0.233338  0.039478     0.041926           9   0.226713
# 10   0.119157  0.011604     0.011778          10   0.117393
# 11   0.333717  0.057476     0.061929          11   0.321671
# 12   0.092174  0.012975     0.012753          12   0.091836
# 13   0.083220  0.042177     0.038085          13   0.086654
# 14   0.127491  0.017531     0.017911          14   0.126017
# 15   0.375085  0.024130     0.025478          15   0.354719
# 16   0.083962  0.028216     0.028429          16   0.083140
# 17   0.061450  0.032163     0.035210          17   0.057175
# 18   0.063682  0.035273     0.037413          18   0.061513
# 19   0.056257  0.017270     0.016701          19   0.058959
# 20   0.083440  0.035560     0.038991          20   0.085424
# 21   0.038808  0.022107     0.020574          21   0.040815
# 22   0.065274  0.053637     0.051589          22   0.067655
# 23   0.032721  0.023308     0.026883          23   0.030475
# 24   0.021038  0.006072     0.006242          24   0.021038
# 25   0.023267  0.018355     0.017430          25   0.024607
# 26   0.030794  0.026077     0.014424          26   0.040182
# 27   0.036204  0.019473     0.017181          27   0.032557
# 28   0.007962  0.010231     0.007489          28   0.010804
# 29   0.001961  0.000974     0.001064          29   0.001832
# ..        ...       ...          ...         ...        ...
# 970  0.001291  0.001995     0.001297          70   0.002032
# 971  0.000684  0.001684     0.000674          71   0.001720
# 972  0.000372  0.000384     0.000369          72   0.000387
# 973  0.001484  0.002828     0.001456          73   0.002893
# 974  0.001527  0.001888     0.001503          74   0.001915
# 975  0.000508  0.000583     0.000504          75   0.000593
# 976  0.000639  0.000483     0.000638          76   0.000487
# 977  0.000814  0.000804     0.000816          77   0.000808
# 978  0.001729  0.004812     0.002096          78   0.004977
# 979  0.000789  0.000701     0.000964          79   0.000709
# 980  0.000229  0.000308     0.000293          80   0.000310
# 981  0.000630  0.000915     0.000784          81   0.000918
# 982  0.000366  0.000811     0.000450          82   0.000806
# 983  0.001417  0.001180     0.001742          83   0.001239
# 984  0.000202  0.000163     0.000250          84   0.000165
# 985  0.000284  0.000298     0.000367          85   0.000298
# 986  0.000779  0.000679     0.000969          86   0.000700
# 987  0.000497  0.000374     0.000645          87   0.000374
# 988  0.000550  0.000749     0.000711          88   0.000744
# 989  0.000939  0.001378     0.001210          89   0.001243
# 990  0.000517  0.000610     0.000660          90   0.000617
# 991  0.000654  0.000576     0.000841          91   0.000576
# 992  0.000216  0.000194     0.000283          92   0.000189
# 993  0.000330  0.000279     0.000417          93   0.000277
# 994  0.000426  0.000594     0.000536          94   0.000608
# 995  0.000195  0.000180     0.000252          95   0.000182
# 996  0.000150  0.000145     0.000188          96   0.000147
# 997  0.000676  0.000721     0.000876          97   0.000715
# 998  0.000186  0.000153     0.000238          98   0.000155
# 999  0.000208  0.000154     0.000264          99   0.000155
#
# [1000 rows x 5 columns]
